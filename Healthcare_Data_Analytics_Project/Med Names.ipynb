# %%
import pandas as pd

# %%
df=pd.read_csv('/content/1000 Generic Medication Names_NHC.txt',sep='\t',header=None)

# %%
df
# Out:
#                                                      0
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
# [1000 rows x 1 columns]

# %%
from numpy import ma
df['Med_Name']=df[0].apply(lambda x:x.split('.',maxsplit=1)[1])

# %%
df
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                                               Med_Name
# 0            Acetaminophen Tablet (500 mg) - Analgesic
# 1     Ibuprofen Tablet (200 mg) - Nonsteroidal Anti...
# 2     Aspirin Tablet (81 mg) - Platelet Aggregation...
# 3     Naproxen Tablet (250 mg) - Nonsteroidal Anti-...
# ...

# %%
df['Med_Class']=df[0].apply(lambda x:x.split('-',maxsplit=1)[1])

# %%
df
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                                               Med_Name  \
# 0            Acetaminophen Tablet (500 mg) - Analgesic
# 1     Ibuprofen Tablet (200 mg) - Nonsteroidal Anti...
# 2     Aspirin Tablet (81 mg) - Platelet Aggregation...
# 3     Naproxen Tablet (250 mg) - Nonsteroidal Anti-...
# ...

# %%
df.drop(columns=['Med_Class'],inplace=True)

# %%
df
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                                               Med_Name
# 0            Acetaminophen Tablet (500 mg) - Analgesic
# 1     Ibuprofen Tablet (200 mg) - Nonsteroidal Anti...
# 2     Aspirin Tablet (81 mg) - Platelet Aggregation...
# 3     Naproxen Tablet (250 mg) - Nonsteroidal Anti-...
# ...

# %%
df['Med_Name']=df['Med_Name'].apply(lambda x:x.split('-',maxsplit=1)[0])

# %%
df
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                                          Med_Name
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ...

# %%
df['Med_Class']=df[0].apply(lambda x:x.split('.',maxsplit=1)[1].split('-',maxsplit=1)[1])

# %%
df
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                                          Med_Name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ...
